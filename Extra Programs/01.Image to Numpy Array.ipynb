# %% [markdown]
# ### Write a Python Program to convert image into numpy  array and show its image size, lower and upper bound of colors used.

# %%
import cv2

# %%
img = cv2.imread("Images/image 1.jpg")

# %%
cv2.imshow('Iron Man',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## Or by using Pillow

# %%
from PIL import Image

# %%
img = Image.open("Images/image 1.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x1B3F9F19310>

# %%
img = np.asarray(img)

# %%
img
# Out:
# array([[[  0,   0,   0],
#         [ 23,  23,  23],
#         [  8,   8,   8],
#         ...,
#         [  0,   0,   0],
#         [  2,   2,   2],
#         [  4,   4,   4]],
#
#        [[  8,   8,   6],
#         [ 12,  12,  12],
#         [  0,   0,   0],
#         ...,
#         [  0,   0,   0],
#         [  2,   2,   2],
#         [  4,   4,   4]],
#
#        [[ 10,  10,   8],
#         [  4,   4,   4],
#         [ 19,  19,  19],
#         ...,
#         [  0,   0,   0],
#         [  2,   2,   2],
#         [  4,   4,   4]],
#
#        ...,
#
#        [[ 96, 106, 118],
#         [ 92, 102, 114],
#         [100, 110, 122],
#         ...,
#         [164, 167, 174],
#         [164, 167, 174],
#         [165, 168, 175]],
#
#        [[ 93, 103, 115],
#         [ 92, 102, 114],
#         [ 97, 107, 119],
#         ...,
#         [164, 167, 174],
#         [166, 169, 176],
#         [168, 171, 178]],
#
#        [[108, 118, 130],
#         [ 98, 108, 120],
#         [ 92, 102, 114],
# ...

# %%
print("The Numpy Array of the Image : \n",img)
# Out:
# The Numpy Array of the Image :
#  [[[  0   0   0]
#   [ 23  23  23]
#   [  8   8   8]
#   ...
#   [  0   0   0]
#   [  2   2   2]
#   [  4   4   4]]
#
#  [[  8   8   6]
#   [ 12  12  12]
#   [  0   0   0]
#   ...
#   [  0   0   0]
#   [  2   2   2]
#   [  4   4   4]]
#
#  [[ 10  10   8]
#   [  4   4   4]
#   [ 19  19  19]
#   ...
#   [  0   0   0]
#   [  2   2   2]
#   [  4   4   4]]
#
#  ...
#
#  [[ 96 106 118]
#   [ 92 102 114]
#   [100 110 122]
#   ...
#   [164 167 174]
#   [164 167 174]
#   [165 168 175]]
#
#  [[ 93 103 115]
#   [ 92 102 114]
#   [ 97 107 119]
#   ...
#   [164 167 174]
#   [166 169 176]
#   [168 171 178]]
#
#  [[108 118 130]
#   [ 98 108 120]
#   [ 92 102 114]
#   ...
#   [162 165 172]
#   [164 167 174]
#   [166 169 176]]]

# %%
print("Image Shape : ",img.shape)
# Out:
# Image Shape :  (1080, 1920, 3)

# %%
colors = ["Blue","Green","Red"]

for idx,col in enumerate(colors):
    arr = img[:,:,idx]
    max_ = max([max(x) for x in arr])
    min_ = min([min(x) for x in arr])
    print(f"The values of Color {col} ranges from the lower bound {min_} and upper bound {max_}")
# Out:
# The values of Color Blue ranges from the lower bound 0 and upper bound 255
# The values of Color Green ranges from the lower bound 0 and upper bound 255
# The values of Color Red ranges from the lower bound 0 and upper bound 255
